# %%
print("%d" % 3)
# Out:
# 3

# %%
print('%f' % 3.5)
# Out:
# 3.500000

# %%
print("%d, %f" % (3, 3.5))
# Out:
# 3, 3.500000

# %%
print("%d, %f, %s" % (3, 3.5, 'hello'))

# %%
not(3>5)
# Out:
# True

# %%
num = 65
print("%c" % num)
# Out:
# A

# %%
age = 21
print(str(19-age))
# Out:
# -2

# %%
num = '10'
print(             + 21)
# Out:
# 31

# %%
num = '10'
print(     int(num)   + 21)
# Out:
# 31
